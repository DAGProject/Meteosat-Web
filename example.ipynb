# %%
#Imports
from matplotlib import pyplot as plt

from camiryo import astro
from camiryo import color

# %%
#Create objects
h5 = astro.H5(verb=True)
ceu = color.Eumetsat(verb=True)

# %%
#Get file's info
file = "MSG_Turkey_202004011000.h5"
info = h5.data(file, "TMet_Info")

# %%
#Vegetation, Snow, Smoke, Dust and Fog (Day)
image_array = ceu.vssdfD(file)

# %%
#Create image
image = ceu.image(image_array)

# %%
#Display image
plt.imshow(image)
plt.show()
